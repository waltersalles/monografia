# %% [markdown]
# <a href="https://colab.research.google.com/github/waltersalles/monografia/blob/main/Monografia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Dados de inflação de 1985 a 1994
inflacao_pre_real = {
    "Ano": [1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994],
    "Inflação (%)": [225.99, 147.14, 228.34, 629.11, 1430.72, 2947.73, 432.79, 951.96, 1927.38, 2075.89]
}

df_pre_real = pd.DataFrame(inflacao_pre_real)

# Exibir tabela
print(df_pre_real)
# Out:
#     Ano  Inflação (%)
# 0  1985        225.99
# 1  1986        147.14
# 2  1987        228.34
# 3  1988        629.11
# 4  1989       1430.72
# 5  1990       2947.73
# 6  1991        432.79
# 7  1992        951.96
# 8  1993       1927.38
# 9  1994       2075.89

# %% [markdown]
# 📊 Tabela 1: Taxas de inflação anuais (1985–1994)
# 📍 Inserir logo após o subtópico 2.7 “Razões do fracasso”

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df_pre_real["Ano"], df_pre_real["Inflação (%)"], marker='o', color='darkred')
plt.title("Inflação Anual no Brasil (1985–1994)")
plt.xlabel("Ano")
plt.ylabel("Inflação (%)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 📈 Gráfico: Inflação anual (1985–1994)

# %%
# Dados de inflação e câmbio no início do Plano Real
real_dados = {
    "Ano": [1994, 1995, 1996, 1997, 1998, 1999, 2000],
    "Inflação (%)": [2075.89, 66.01, 15.76, 6.93, 3.20, 4.86, 7.04],
    "Câmbio (BRL/USD)": [None, 0.92, 1.01, 1.08, 1.16, 1.82, 1.83]
}

df_real = pd.DataFrame(real_dados)

# Exibir tabela
print(df_real)
# Out:
#     Ano  Inflação (%)  Câmbio (BRL/USD)
# 0  1994       2075.89               NaN
# 1  1995         66.01              0.92
# 2  1996         15.76              1.01
# 3  1997          6.93              1.08
# 4  1998          3.20              1.16
# 5  1999          4.86              1.82
# 6  2000          7.04              1.83

# %% [markdown]
# 📊 Tabela 2: Taxas de inflação e câmbio (1994–2000)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.set_title("Inflação e Câmbio no Brasil (1994–2000)")
ax1.set_xlabel("Ano")
ax1.set_ylabel("Inflação (%)", color='tab:red')
ax1.plot(df_real["Ano"], df_real["Inflação (%)"], color='tab:red', marker='o', label='Inflação')
ax1.tick_params(axis='y', labelcolor='tab:red')

ax2 = ax1.twinx()
ax2.set_ylabel("Câmbio (BRL/USD)", color='tab:blue')
ax2.plot(df_real["Ano"][1:], df_real["Câmbio (BRL/USD)"][1:], color='tab:blue', marker='s', label='Câmbio')
ax2.tick_params(axis='y', labelcolor='tab:blue')

fig.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# 📈 Gráfico: Inflação e câmbio (1994–2000)

# %%
# Dados do período Dilma
dilma_dados = {
    "Ano": [2010, 2011, 2012, 2013, 2014, 2015, 2016],
    "Inflação (%)": [5.04, 6.64, 5.40, 6.20, 6.33, 9.03, 8.74],
    "Câmbio (BRL/USD)": [1.76, 1.67, 1.95, 2.16, 2.35, 3.34, 3.48]
}

df_dilma = pd.DataFrame(dilma_dados)

# Exibir tabela
print(df_dilma)
# Out:
#     Ano  Inflação (%)  Câmbio (BRL/USD)
# 0  2010          5.04              1.76
# 1  2011          6.64              1.67
# 2  2012          5.40              1.95
# 3  2013          6.20              2.16
# 4  2014          6.33              2.35
# 5  2015          9.03              3.34
# 6  2016          8.74              3.48

# %% [markdown]
# ✅ Capítulo 4 – Perda de estabilidade no governo Dilma (2010–2016)
# 📊 Tabela 3: Inflação e câmbio (2010–2016)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.set_title("Inflação e Câmbio no Brasil (2010–2016)")
ax1.set_xlabel("Ano")
ax1.set_ylabel("Inflação (%)", color='tab:red')
ax1.plot(df_dilma["Ano"], df_dilma["Inflação (%)"], color='tab:red', marker='o', label='Inflação')
ax1.tick_params(axis='y', labelcolor='tab:red')

ax2 = ax1.twinx()
ax2.set_ylabel("Câmbio (BRL/USD)", color='tab:blue')
ax2.plot(df_dilma["Ano"], df_dilma["Câmbio (BRL/USD)"], color='tab:blue', marker='s', label='Câmbio')
ax2.tick_params(axis='y', labelcolor='tab:blue')

fig.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# 📈 Gráfico: Inflação e câmbio (2010–2016)
